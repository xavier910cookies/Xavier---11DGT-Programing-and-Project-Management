# %% [markdown]
# ## Python Student Exercises 1
# #### Auther: Xavier J. Cook
# #### Date: 16 June 2026
# #### Version: 1.0
#
# 1. program to print name, adress and telephone number in separate

# %%
import time

name = 'Xavier Cook'
address = '67 Beach road, marine lane'
tel = '### ### ####'
print (name,address,tel,sep='\n')

time.sleep(2)

print("\nYou didn't think that i would show you my adress and tel number did you?")

# %% [markdown]
# 2. WAP that will ask the users name, save it in a variable and will then printout
#
# Hello ____
#
# with the name included (eg Hello George).

# %% [markdown]
# 3. WAP that will ask the user for a number, save it in a variable called num and will then print out the following information using that number, with each statement on a different line.
#
# The number is ___
# 5 times ____ is _____
#
# if you add 3 to ____ the answer is _____
#
# if you divide 20 by _____ the answer is ______
#
#
# You may add some other calculations of your own.

# %%
num = float(input('hi, please input any number\n'))
print(f'The number is {num}.')
print()

# %% [markdown]
# 4. WAP that will ask for a particular number of inches and will convert that number to cm, with an output like
#
# ______ inches is equal to _______ cm
#
# (1 inch = 2.54 cm)

# %%
raw_inches = input('Please enter amount of inches')
inches

# %% [markdown]
# 5. WAP that will ask the user’s age and then outputs a statement saying
#
# Your current age is _________
# In the year 2050 you will be ______ years old

# %%
user_age = int(input('please enter your age'))

# %%
# calculate age more effecttivly
from datetime import datetime, date

print("Your date of birth in this format please: (dd mm yyyy)\n")
date_of_birth = datetime.strptime(input("--->"), "%d %m %y")

def calculate_age(born):
    today = date.today
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))
